# %% [markdown]
# # Global Terrorism exploration and prediction APP

# %% [markdown]
# ## Dataset

# %% [markdown]
# The Global Terrorism Database (GTD) documents more than 200,000 international and domestic terrorist attacks that occurred worldwide since 1970. With details on various dimensions of each attack, the GTD familiarizes analysts, policymakers, scholars, and journalists with patterns of terrorism. The GTD defines terrorist attacks as: The threatened or actual use of illegal force and violence by a non-state actor to attain a political, economic, religious, or social goal through fear, coercion, or intimidation. Data collection is ongoing and updates are published annually at www.start.umd.edu/gtd.
#
# This dataset is available: https://www.kaggle.com/START-UMD/gtd/data, in the document called: <b>globalterrorismdb_0718dist.csv </b>

# %% [markdown]
# ## Project Goals

# %% [markdown]
# The goal of the project is to understand more about the global terrorism, using an exploration app in streamlit that allow to understand better the terrorism in each country: terrorist groups, attacks, more dangerous cities, most frequent acts of terror // Increase to..do//
#
# Having a good approach about the trends during all the period (1970 til.2017) like, if the terrorist attacks are increasing or decreasing... what kind of terrorist atacks are being on trend.... can we predict which region or regions will have a terrorist attack and which kind? can we predict the number of victims?
#
# //Increase to..do//

# %% [markdown]
# ## Importing Libreries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Importing data

# %%
df = pd.read_csv("global_terror.csv",encoding="Latin-1")
# Out:
# C:\Users\APC\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning:
#
# Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ## Data Cleaning

# %%
df = df[['iyear','imonth','iday','country_txt','country','region_txt',
         'region','provstate','city',
         'latitude', 'longitude','success','suicide', 'attacktype1_txt',
         'attacktype1', 'targtype1_txt', 'targtype1',
         'gname', 'weaptype1_txt','weaptype1',
         'nkill','nwound']]

# %%
df.head()
# Out:
#    iyear  imonth  iday         country_txt  country  \
# 0   1970       7     2  Dominican Republic       58
# 1   1970       0     0              Mexico      130
# 2   1970       1     0         Philippines      160
# 3   1970       1     0              Greece       78
# 4   1970       1     0               Japan      101
#
#                     region_txt  region provstate           city   latitude  \
# 0  Central America & Caribbean       2       NaN  Santo Domingo  18.456792
# 1                North America       1   Federal    Mexico city  19.371887
# 2               Southeast Asia       5    Tarlac        Unknown  15.478598
# 3               Western Europe       8    Attica         Athens  37.997490
# 4                    East Asia       4   Fukouka        Fukouka  33.580412
#
#    ...  suicide                 attacktype1_txt  attacktype1  \
# 0  ...        0                   Assassination            1
# 1  ...        0     Hostage Taking (Kidnapping)            6
# 2  ...        0                   Assassination            1
# 3  ...        0               Bombing/Explosion            3
# 4  ...        0  Facility/Infrastructure Attack            7
#
#                  targtype1_txt  targtype1                               gname  \
# 0  Private Citizens & Property         14                              MANO-D
# 1      Government (Diplomatic)          7  23rd of September Communist League
# 2          Journalists & Media         10                             Unknown
# 3      Government (Diplomatic)          7                             Unknown
# 4      Government (Diplomatic)          7                             Unknown
#
#    weaptype1_txt weaptype1 nkill  nwound
# 0        Unknown        13   1.0     0.0
# 1        Unknown        13   0.0     0.0
# 2        Unknown        13   1.0     0.0
# 3     Explosives         6   NaN     NaN
# 4     Incendiary         8   NaN     NaN
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 22 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   iyear            181691 non-null  int64
#  1   imonth           181691 non-null  int64
#  2   iday             181691 non-null  int64
#  3   country_txt      181691 non-null  object
#  4   country          181691 non-null  int64
#  5   region_txt       181691 non-null  object
#  6   region           181691 non-null  int64
#  7   provstate        181270 non-null  object
#  8   city             181257 non-null  object
#  9   latitude         177135 non-null  float64
#  10  longitude        177134 non-null  float64
#  11  success          181691 non-null  int64
#  12  suicide          181691 non-null  int64
#  13  attacktype1_txt  181691 non-null  object
#  14  attacktype1      181691 non-null  int64
#  15  targtype1_txt    181691 non-null  object
#  16  targtype1        181691 non-null  int64
#  17  gname            181691 non-null  object
#  18  weaptype1_txt    181691 non-null  object
#  19  weaptype1        181691 non-null  int64
#  20  nkill            171378 non-null  float64
#  21  nwound           165380 non-null  float64
# dtypes: float64(4), int64(10), object(8)
# memory usage: 30.5+ MB

# %%
df.isnull().sum()
# Out:
# iyear                  0
# imonth                 0
# iday                   0
# country_txt            0
# country                0
# region_txt             0
# region                 0
# provstate            421
# city                 434
# latitude            4556
# longitude           4557
# success                0
# suicide                0
# attacktype1_txt        0
# attacktype1            0
# targtype1_txt          0
# targtype1              0
# gname                  0
# weaptype1_txt          0
# weaptype1              0
# nkill              10313
# nwound             16311
# dtype: int64

# %%
df['iday'].value_counts()
df['iday'].replace(to_replace=0, value=np.random.randint(1, 29), inplace=True)
df['iday'].value_counts()
# Out:
# 9     6948
# 15    6500
# 1     6344
# 4     6153
# 16    6112
# 10    6064
# 13    6043
# 14    6028
# 28    6027
# 12    6012
# 3     6011
# 7     5997
# 19    5973
# 2     5954
# 27    5937
# 11    5936
# 20    5930
# 18    5880
# 25    5875
# 8     5859
# 17    5852
# 5     5844
# 21    5827
# 26    5823
# 22    5799
# 23    5782
# 6     5781
# 24    5752
# 29    5507
# 30    5046
# 31    3095
# Name: iday, dtype: int64

# %%
df['imonth'].value_counts()
df['imonth'].replace(to_replace=0, value=np.random.randint(1, 13), inplace=True)
df['imonth'].value_counts()
# Out:
# 5     16875
# 7     16268
# 8     15820
# 10    15563
# 6     15359
# 3     15257
# 4     15152
# 1     14936
# 11    14906
# 9     14180
# 2     13879
# 12    13496
# Name: imonth, dtype: int64

# %%
df2 = df[["iyear", "imonth", "iday"]].copy()
df2.columns = ["year", "month", "day"]
pd.to_datetime(df2)
df["idate"] = pd.to_datetime(df2)
cols = list(df.columns)
cols = [cols[-1]] + cols[:-1]
df = df[cols]
df
# Out:
#             idate  iyear  imonth  iday         country_txt  country  \
# 0      1970-07-02   1970       7     2  Dominican Republic       58
# 1      1970-08-09   1970       8     9              Mexico      130
# 2      1970-01-09   1970       1     9         Philippines      160
# 3      1970-01-09   1970       1     9              Greece       78
# 4      1970-01-09   1970       1     9               Japan      101
# ...           ...    ...     ...   ...                 ...      ...
# 181686 2017-12-31   2017      12    31             Somalia      182
# 181687 2017-12-31   2017      12    31               Syria      200
# 181688 2017-12-31   2017      12    31         Philippines      160
# 181689 2017-12-31   2017      12    31               India       92
# 181690 2017-12-31   2017      12    31         Philippines      160
#
#                          region_txt  region        provstate           city  \
# 0       Central America & Caribbean       2              NaN  Santo Domingo
# 1                     North America       1          Federal    Mexico city
# 2                    Southeast Asia       5           Tarlac        Unknown
# 3                    Western Europe       8           Attica         Athens
# 4                         East Asia       4          Fukouka        Fukouka
# ...                             ...     ...              ...            ...
# 181686           Sub-Saharan Africa      11  Middle Shebelle  Ceelka Geelow
# 181687   Middle East & North Africa      10         Lattakia         Jableh
# 181688               Southeast Asia       5      Maguindanao       Kubentog
# 181689                   South Asia       6          Manipur         Imphal
# 181690               Southeast Asia       5      Maguindanao  Cotabato City
#
#         ...  suicide                 attacktype1_txt  attacktype1  \
# 0       ...        0                   Assassination            1
# 1       ...        0     Hostage Taking (Kidnapping)            6
# 2       ...        0                   Assassination            1
# 3       ...        0               Bombing/Explosion            3
# 4       ...        0  Facility/Infrastructure Attack            7
# ...     ...      ...                             ...          ...
# 181686  ...        0                   Armed Assault            2
# 181687  ...        0               Bombing/Explosion            3
# 181688  ...        0  Facility/Infrastructure Attack            7
# 181689  ...        0               Bombing/Explosion            3
# 181690  ...        0               Bombing/Explosion            3
#
#                       targtype1_txt targtype1  \
# 0       Private Citizens & Property        14
# 1           Government (Diplomatic)         7
# 2               Journalists & Media        10
# 3           Government (Diplomatic)         7
# 4           Government (Diplomatic)         7
# ...                             ...       ...
# 181686                     Military         4
# 181687                     Military         4
# 181688  Private Citizens & Property        14
# 181689         Government (General)         2
# 181690                      Unknown        20
#
#                                              gname weaptype1_txt  weaptype1  \
# 0                                           MANO-D       Unknown         13
# 1               23rd of September Communist League       Unknown         13
# 2                                          Unknown       Unknown         13
# 3                                          Unknown    Explosives          6
# 4                                          Unknown    Incendiary          8
# ...                                            ...           ...        ...
# 181686                                  Al-Shabaab      Firearms          5
# 181687                           Muslim extremists    Explosives          6
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)    Incendiary          8
# 181689                                     Unknown    Explosives          6
# 181690                                     Unknown    Explosives          6
#
#        nkill nwound
# 0        1.0    0.0
# 1        0.0    0.0
# 2        1.0    0.0
# 3        NaN    NaN
# 4        NaN    NaN
# ...      ...    ...
# 181686   1.0    2.0
# 181687   2.0    7.0
# 181688   0.0    0.0
# 181689   0.0    0.0
# 181690   0.0    0.0
#
# [181691 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   idate            181691 non-null  datetime64[ns]
#  1   iyear            181691 non-null  int64
#  2   imonth           181691 non-null  int64
#  3   iday             181691 non-null  int64
#  4   country_txt      181691 non-null  object
#  5   country          181691 non-null  int64
#  6   region_txt       181691 non-null  object
#  7   region           181691 non-null  int64
#  8   provstate        181270 non-null  object
#  9   city             181257 non-null  object
#  10  latitude         177135 non-null  float64
#  11  longitude        177134 non-null  float64
#  12  success          181691 non-null  int64
#  13  suicide          181691 non-null  int64
#  14  attacktype1_txt  181691 non-null  object
#  15  attacktype1      181691 non-null  int64
#  16  targtype1_txt    181691 non-null  object
#  17  targtype1        181691 non-null  int64
#  18  gname            181691 non-null  object
#  19  weaptype1_txt    181691 non-null  object
#  20  weaptype1        181691 non-null  int64
#  21  nkill            171378 non-null  float64
#  22  nwound           165380 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(10), object(8)
# memory usage: 31.9+ MB

# %%
## As we see there are missing values in columns nkill nwound, as the amount of
## missing values are more than 8%, we could not proceed removing those rows with mising values in both columns 
## so we will substitute those values with a average data so we will not affect to our training data

df['nkill'].fillna((df['nkill'].mean()), inplace=True)
df['nwound'].fillna((df['nwound'].mean()), inplace=True)

# %%
df["nkill"] = df["nkill"].astype(int)
df["nwound"] = df["nwound"].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   idate            181691 non-null  datetime64[ns]
#  1   iyear            181691 non-null  int64
#  2   imonth           181691 non-null  int64
#  3   iday             181691 non-null  int64
#  4   country_txt      181691 non-null  object
#  5   country          181691 non-null  int64
#  6   region_txt       181691 non-null  object
#  7   region           181691 non-null  int64
#  8   provstate        181270 non-null  object
#  9   city             181257 non-null  object
#  10  latitude         177135 non-null  float64
#  11  longitude        177134 non-null  float64
#  12  success          181691 non-null  int64
#  13  suicide          181691 non-null  int64
#  14  attacktype1_txt  181691 non-null  object
#  15  attacktype1      181691 non-null  int64
#  16  targtype1_txt    181691 non-null  object
#  17  targtype1        181691 non-null  int64
#  18  gname            181691 non-null  object
#  19  weaptype1_txt    181691 non-null  object
#  20  weaptype1        181691 non-null  int64
#  21  nkill            181691 non-null  int32
#  22  nwound           181691 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(10), object(8)
# memory usage: 30.5+ MB

# %%
df.to_csv("Terrorism_preprocessed.csv",index=False)

# %%
#With regards to the rows with no information in latitude and longitud, there are 4557 rows over 181691, this means a 2.5% or our data set.
#from those rows 2295 the city or provstate is unknown, 
df = df.dropna(subset=['longitude'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177134 entries, 0 to 181690
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   idate            177134 non-null  datetime64[ns]
#  1   iyear            177134 non-null  int64
#  2   imonth           177134 non-null  int64
#  3   iday             177134 non-null  int64
#  4   country_txt      177134 non-null  object
#  5   country          177134 non-null  int64
#  6   region_txt       177134 non-null  object
#  7   region           177134 non-null  int64
#  8   provstate        176725 non-null  object
#  9   city             176708 non-null  object
#  10  latitude         177134 non-null  float64
#  11  longitude        177134 non-null  float64
#  12  success          177134 non-null  int64
#  13  suicide          177134 non-null  int64
#  14  attacktype1_txt  177134 non-null  object
#  15  attacktype1      177134 non-null  int64
#  16  targtype1_txt    177134 non-null  object
#  17  targtype1        177134 non-null  int64
#  18  gname            177134 non-null  object
#  19  weaptype1_txt    177134 non-null  object
#  20  weaptype1        177134 non-null  int64
#  21  nkill            177134 non-null  int32
#  22  nwound           177134 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(10), object(8)
# memory usage: 31.1+ MB

# %%
df2 = df[df["provstate"].isnull()]
df2[df2["city"].isnull()]
# Out:
# Empty DataFrame
# Columns: [idate, iyear, imonth, iday, country_txt, country, region_txt, region, provstate, city, latitude, longitude, success, suicide, attacktype1_txt, attacktype1, targtype1_txt, targtype1, gname, weaptype1_txt, weaptype1, nkill, nwound]
# Index: []
#
# [0 rows x 23 columns]

# %%
df3 = df[df["city"].isnull()]
df3[df3["provstate"].isnull()]
# Out:
# Empty DataFrame
# Columns: [idate, iyear, imonth, iday, country_txt, country, region_txt, region, provstate, city, latitude, longitude, success, suicide, attacktype1_txt, attacktype1, targtype1_txt, targtype1, gname, weaptype1_txt, weaptype1, nkill, nwound]
# Index: []
#
# [0 rows x 23 columns]

# %%
##THIS MEANS THAT when the city is non value the provstate has value and the contrary also happens, so no cleaning is need it

# %%
df.to_csv("Terrorism_clean_dataset.csv",index=False)

# %% [markdown]
# ## Exploring data

# %% [markdown]
# ### Visualization of outliers

# %% [markdown]
# An outlier is a data point that lies outside the overall pattern in a distribution. A commonly used rule says that a data point is an outlier if it is more than 1.5 IQR above the third quartile or below the first quartile. Said differently, low outliers are below Q1 -1.5 * IQR  and high outliers are above Q3 +1.5 IQR

# %%
df[['nkill', 'nwound']].plot.box()
# Out:
# <AxesSubplot:>

# %%
# Looking for outliers
df[['nkill', 'nwound']].describe()
# Out:
#                nkill         nwound
# count  177134.000000  177134.000000
# mean        2.341628       3.177967
# std        11.158855      34.712222
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         1.000000       0.000000
# 75%         2.000000       3.000000
# max      1570.000000    8191.000000

# %%
#Function to show outliers using the 1.5 IQR method 
#IQR = Q3 - Q1
    # lower outliers are below  Q1 - 1.5 * IQR  
    # Higher ouliers  are above  Q3 + 1.5 * IQR 
    
a = np.array(df.nkill)
upper_quartile = np.percentile(a, 75)
lower_quartile = np.percentile(a, 25)
iqr15 = (upper_quartile - lower_quartile) * 1.5
quartile_set = (lower_quartile - iqr15, upper_quartile + iqr15)
quartile_set
# Out:
# (-3.0, 5.0)

# %% [markdown]
# ## Trend analysis (Goal 1) (to-DO)

# %%
# Plot with the Terrorist Attacks from 1970 to 2016
sns.set_theme(style="darkgrid")
plt.figure(figsize=(23, 10))
sns.countplot('iyear', data=df, palette="Set3")
plt.title('Global Terrorism: Terrorist Attacks from 1970 to 2016', fontsize=23)
plt.xticks(rotation=90, fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel('Year', fontsize=20) 
plt.ylabel('Count', fontsize=20)
# Out:
# C:\Users\APC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# Text(0, 0.5, 'Count')

# %%
# Groupby number of people killed per year


# df_total_killed_year = df.groupby(['iyear'])['nkill'].sum().to_frame(name = 'Total_sum').reset_index()
df_total_killed_year = df.groupby('iyear').agg(Total_killed=('nkill', 'sum'), Total_attacks=('nkill', 'count'), Mean_killed= ('nkill','mean')).reset_index()
df_total_killed_year
# Out:
#     iyear  Total_killed  Total_attacks  Mean_killed
# 0    1970           218            643     0.339036
# 1    1971           296            463     0.639309
# 2    1972           626            551     1.136116
# 3    1973           462            465     0.993548
# 4    1974           649            577     1.124783
# 5    1975           911            727     1.253095
# 6    1976           849            900     0.943333
# 7    1977           691           1292     0.534830
# 8    1978          1666           1455     1.145017
# 9    1979          2575           2533     1.016581
# 10   1980          5030           2561     1.964077
# 11   1981          5769           2469     2.336574
# 12   1982          6393           2408     2.654900
# 13   1983          9557           2670     3.579401
# 14   1984          9822           3198     3.071295
# 15   1985          6675           2680     2.490672
# 16   1986          5232           2680     1.952239
# 17   1987          6206           2989     2.076280
# 18   1988          6300           3471     1.815039
# 19   1989          7588           4147     1.829756
# 20   1990          6482           3648     1.776864
# 21   1991          7895           4405     1.792281
# 22   1992          8555           4832     1.770488
# 23   1994          7233           3295     2.195144
# 24   1995          5700           2920     1.952055
# 25   1996          6135           2909     2.108972
# 26   1997          9989           2996     3.334112
# 27   1998          4206            891     4.720539
# 28   1999          3349           1341     2.497390
# 29   2000          4421           1772     2.494921
# 30   2001          7426           1883     3.943707
# 31   2002          4700           1310     3.587786
# 32   2003          3334           1263     2.639747
# 33   2004          5687           1137     5.001759
# 34   2005          6284           1985     3.165743
# 35   2006          9332           2716     3.435935
# 36   2007         12769           3190     4.002821
# 37   2008          9190           4756     1.932296
# 38   2009          9285           4706     1.973013
# 39   2010          7817           4818     1.622457
# 40   2011          8252           5048     1.634707
# 41   2012         15871           8470     1.873790
# 42   2013         22843          11926     1.915395
# 43   2014         46308          16794     2.757413
# 44   2015         40272          14861     2.709912
# 45   2016         36373          13530     2.688322
# 46   2017         27559          10853     2.539298

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(23, 10))
mean=df_total_killed_year['Mean_killed']
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="iyear", y="Total_killed", data=df_total_killed_year)
             
plt.title('Global Terrorism: Number of people killed in Terrorist Attacks from 1970 to 2016', fontsize=23)
plt.xticks(rotation=90, fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel('Year', fontsize=20) 
plt.ylabel('Total people killed', fontsize=20)
# Out:
# Text(0, 0.5, 'Total people killed')
